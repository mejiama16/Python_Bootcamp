# %% [markdown]
# # Day 1 Exercises
# ## Data Types

# %% [markdown]
# #### 1. What types are involved in the following expressions? What data type will each expression evaluate to?

# %%
8 * 2.5
# Out:
# 20.0

# %% [markdown]
# 8 is an integer and 2.5 is a float. This expression will return a float.

# %%
9 / 2
# Out:
# 4.5

# %% [markdown]
# Both 9 and 2 are integers, this expression will return a float.

# %%
1.5 * 2 >= 7 - 3
# Out:
# False

# %% [markdown]
# This expression involves integers and floats. It will return a boolean (true of false).

# %% [markdown]
# #### 2. In which order will the expressions be evaluated?

# %%
6 * 3 + 7 * 4
# Out:
# 46

# %% [markdown]
# First, Python evaluates the multiplications, 6 times 3 and 7 times 4. Then, it adds the results of these together (18+28 = 46).

# %%
5 - 2 * 3 ** 4
# Out:
# -157

# %% [markdown]
# First, Python evaluates 3 to the power of 4 (81). Then, this value get's multiplied by 2 (162). Lastly, the resulted value is subtracted from 5 (5-162 = -157).

# %%
(5 - 2) * 3 ** 4
# Out:
# 243

# %% [markdown]
# Python evaluates 5 minus 2 and 3 to the power of 4 separately. Then, it multiplies these results together (3 x 81 = 243).

# %%
5 + 2 >= 3 * 4
# Out:
# False

# %% [markdown]
# Python evaluates 5 plus 2 and 3 times 4 separately. Then evaluates whether 5 plus 2 (7) is greater than or equal to 3 times 4 (12) to return True or False. In this case, since 7 is smaller than 12, it will return False.

# %% [markdown]
# ## Comments and Errors

# %% [markdown]
# #### 1. Which of these expressions results in an error? Why does each error occur?

# %%
((((5 * 4 ** 7))))
# Out:
# 81920

# %% [markdown]
# No error

# %%
84 *= 0.5 / 7
# Out:
#   File "/tmp/ipykernel_3218/868797654.py", line 1
#     84 *= 0.5 / 7
#     ^
# SyntaxError: 'literal' is an illegal expression for augmented assignment

# %% [markdown]
# This expression results in an error because *= is not a valid operator.

# %%
(-(-(-(-5 * (4 + 3)))))
# Out:
# 35

# %% [markdown]
# No error

# %%
5 * 3 = weight
# Out:
#   File "/tmp/ipykernel_3218/3700621706.py", line 1
#     5 * 3 = weight
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %% [markdown]
# This expression results in an error because = is not a valid boolean operator. To evaluate whether these expressions are equal, we should use ==, double equal signs.

# %%
73 / -----------5
# Out:
# -14.6

# %% [markdown]
# No error

# %% [markdown]
# #### 2. Write a block of code to check if the value is a string. If it is, print out a message saying it is valid. Otherwise, raise an exception with a message saying the value must be a string.

# %%
value = 6
# Your code goes here
if type(value) == str:
  print("The value is valid")
else:
  print("The value must be a string")
# Out:
# The value must be a string

# %% [markdown]
# #### 3. What are the following errors?

# %%
arr = [1, 2, 3]
print(arr[3])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_3218/2963248189.py in <cell line: 0>()
#       1 arr = [1, 2, 3]
# ----> 2 print(arr[3])
#
# IndexError: list index out of range

# %% [markdown]
# This error happens because the array doesn't have an index 3. Although it has 3 elements, the indeces start from 0, so we get indeces (0, 1, 2) on each element of the array; rather than (1, 2, 3). As a result, we cannot retrieve the *third* element, using index 3. Instead, we should use print(arr[2]) if we wanted to print the last element of the array.

# %%
fullName = "Taylor Swift"
print(full_name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3218/3996353418.py in <cell line: 0>()
#       1 fullName = "Taylor Swift"
# ----> 2 print(full_name)
#
# NameError: name 'full_name' is not defined

# %% [markdown]
# Variable names are case sensitive and must be called exactly as they are created. In this case, the defined variable is called fullName, rather than full_name, as we call within print(). Since full_name is not defined, we get an error when trying to print it.

# %%
2 + '2' + 4
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3218/1647341539.py in <cell line: 0>()
# ----> 1 2 + '2' + 4
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# We cannot use the addition operator across different data types as this will result in an error as shown above.

# %% [markdown]
# ## Functions

# %% [markdown]
# #### 1. Following the function design recipe, define a function that converts kilometers into miles. (Assume there are 1.6 kilometers in a mile.)

# %%
def km_to_mi(km):
  """
  Convert kilometers into miles.
  Parameter: km (number of kilometers, int or float)
  Return: corresponding number of miles (float)
  """
  return km/1.6

# %% [markdown]
# #### 2. What value is printed in the below code?

# %%
answer = 3

def answer_to_everything():
    '''Return the answer to life, the universe, and everything'''
    answer = 42
    return answer

answer_to_everything()

print(answer)
# Out:
# 3

# %% [markdown]
# #### 3. Complete the body of the function. You can assume num is always >= 0.

# %%
def repeat(string, num):
    ''' Return string repeated num times.
    >>> repeat('yes', 4)
    'yesyesyesyes'
    >>> repeat('no', 0)
    ''
    >>> repeat('yesnomaybe', 3)
    'yesnomaybeyesnomaybeyesnomaybe'
    '''
    output = string * num
    return output

# %% [markdown]
# #### 4. Complete the function below. You can assume that number will always be a string with 10 digits and that the first 3 digits will always be the area code.

# %%
def is_416_number(number):
    ''' Check whether the number has a 416 area code.
    >>> is_416_number('(416)-555-5555')
    True
    >>> is_416_number('514 416 5555')
    False
    >>> is_416_number('4165554160')
    True
    '''
    # Your code goes here
    # Hint: replace () and spaces with nothing
    number = number.replace('(', '')
    number = number.replace(')', '')
    number = number.replace(' ', '')
    number = number.replace('-', '')
    area_code = int(number[0:3])
    return area_code == 416

# Check:
is_416_number('(416)-555-5555')
# Out:
# True

# %%
# Check
is_416_number('514 416 5555')
# Out:
# False

# %%
# Check
is_416_number('4165554160')
# Out:
# True
